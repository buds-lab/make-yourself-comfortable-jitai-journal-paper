# %% [markdown]
# # Keep only one weekly survey response per week
#  - Author: Mario Frei, 2025

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Configurations

# %%
weekly_survey_path = '../2_processing/4_weekly_survey_with_personality.csv'

# %% [markdown]
# ## Process data

# %%
# Read data
df = pd.read_csv(weekly_survey_path)

# Replace NaN with 'No response provided'
df = df.fillna('No response')

# Save data
df.head()
# Out:
#   id_participant                         timestamp This app is easy to use.  \
# 0       orenth01  2022-10-10 14:22:56.671000+00:00        Strongly disagree
# 1       orenth01  2022-10-20 01:44:32.965000+00:00        Strongly disagree
# 2       orenth01  2022-10-26 07:31:27.555000+00:00                  Neutral
# 3       orenth02  2022-10-12 01:13:47.044000+00:00                    Agree
# 4       orenth02  2022-10-17 01:01:01.540000+00:00             Strong Agree
#
#   How often do you wear your watch in a week?  \
# 0                                 40-50 hours
# 1                                   >50 hours
# 2                                   >50 hours
# 3                                 10-20 hours
# 4                                   <10 hours
#
#   The notifications on the watch were annoying.  \
# 0                                       Neutral
# 1                             Strongly disagree
# 2                                         Agree
# ...

# %% [markdown]
# # Save data

# %%
df.to_csv('../2_processing/5_weekly_survey_with_personality_no_nan.csv', index=False)
